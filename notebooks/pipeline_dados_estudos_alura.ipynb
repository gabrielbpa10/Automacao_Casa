# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrielbpa10/Automacao_Casa/blob/master/notebooks/pipeline_dados_estudos_alura.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Teste')
# Out:
# Teste
